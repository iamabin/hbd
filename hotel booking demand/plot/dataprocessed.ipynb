# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./hotel_bookings.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.drop(["company"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-baf500706516> in <module>
# ----> 1 df.drop(["company"])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
# type of hotel
typeofhotel = df.hotel
resort_hotel = 0
city_hotel = 0
for index in range(len(typeofhotel)):
    if typeofhotel[index] == "Resort Hotel":
        resort_hotel = resort_hotel + 1
for index in range(len(typeofhotel)):
    if typeofhotel[index] == "City Hotel":
        city_hotel = city_hotel + 1
total_num_of_hotel = city_hotel + resort_hotel
print(resort_hotel)
print(city_hotel)
print(total_num_of_hotel)
# Out:
# 40060
# 79330
# 119390

# %%
# pie chart
import matplotlib as mpl
import matplotlib.pyplot as plt
labels = ['Resort hotel', 'City hotel']
share = [cr/numofhotel,cc/numofhotel]
explode = [0, 0]
plt.pie(share, explode = explode,
        labels = labels, autopct = '%3.2f%%',
        startangle = 90, shadow = True,
        colors = ['orange', 'cornflowerblue'])


plt.title("Comparison of booking of different types of hotel")
plt.savefig("type_hotel1.png")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# cancel rate vs type of hotel
cancel_col=df.is_canceled
r_cancel=0;
c_cancel=0;

for index in range(0,40060):
    if cancel_col[index] == 1:
        r_cancel = r_cancel + 1
for index in range(40061,119390):
    if cancel_col[index] == 1:
        c_cancel = c_cancel + 1

print(r_cancel)
print(c_cancel)
# Out:
# 11122
# 33102

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# set the size of char 
plt.figure(figsize = (10, 8))

# 生成数据
labels = ['Canceled', 'Unanceled', 'Resort hotel Canceled', 'City hotel canceled','a','b']
share_laptop = [0.370416, 1-0.370416]
share_pc = [0.0931, 0.277259, 0.24238, 0.38720]
color = ['sandybrown', 'orange', 'lightsteelblue', 'skyblue']
colors2 = ['darkorange','steelblue']

# 外环
wedges1, texts1, autotexts1 = plt.pie(share_pc,
    autopct = '%3.1f%%',
    radius = 1,
    pctdistance = 0.85,
    colors = color,
    startangle = 180,
    textprops = {'color': 'w'},
    wedgeprops = {'width': 0.3, 'edgecolor': 'w'}
)

# 内环
wedges2, texts2, autotexts2 = plt.pie(share_laptop,
    autopct = '%3.1f%%',
    radius = 0.7,
    pctdistance = 0.75,
    colors = colors2,
    startangle = 180,
    textprops = {'color': 'w'},
    wedgeprops = {'width': 0.3, 'edgecolor': 'w'}
)

# 图例
plt.legend(wedges1,
          labels,
          fontsize = 12,
          title = 'lable',
          loc = 'center left',
          bbox_to_anchor = (1, 0.6))

# 设置文本样式
plt.setp(autotexts1, size=15, weight='bold')
plt.setp(autotexts2, size=15, weight='bold')
plt.setp(texts1, size=15)

# 标题
plt.title('cancel', fontsize=20)

plt.show()

# %%
m1=0
m2=0
m3=0
m4=0
m5=0
m6=0
m7=0
m8=0
m9=0
m10=0
m11=0
m12=0
mon_col=df.arrival_date_month

# %%
# how long do people usually stay?
stayweekend_r = df.stays_in_weekend_nights
stayweek_r = df.stays_in_week_nights
len_stay={}
for index in range(0,119390):
    len_stay[index] = stayweekend_r[index]+stayweek_r[index]
    
one_night = 0
two_night = 0
three_night = 0
four_night = 0
five_night = 0
six_night = 0
seven_night = 0
eight_night = 0
nine_night = 0
overten_night = 0
for index in range(0,40060):
    if len_stay[index] == 1:
        one_night = one_night + 1
for index in range(0,40060):
    if len_stay[index] == 2:
        two_night = two_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 3:
        three_night = three_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 4:
        four_night = four_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 5:
        five_night = five_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 6:
        six_night = six_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 7:
        seven_night = seven_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 8:
        eight_night = eight_night + 1
        
for index in range(0,40060):
    if len_stay[index] == 9:
        nine_night = nine_night + 1
        
for index in range(0,40060):
    if len_stay[index] >= 10:
        overten_night = overten_night + 1
        
print(one_night )
print(two_night )
print(three_night )
print(four_night )
print(five_night )
print(six_night )
print(seven_night )
print(eight_night )
print(nine_night )
print(overten_night )




one_night_c = 0
two_night_c = 0
three_night_c = 0
four_night_c = 0
five_night_c = 0
six_night_c = 0
seven_night_c = 0
eight_night_c = 0
nine_night_c = 0
overten_night_c = 0
for index in range(40061,119390):
    if len_stay[index] == 1:
        one_night_c = one_night_c + 1
for index in range(40061,119390):
    if len_stay[index] == 2:
        two_night_c = two_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 3:
        three_night_c = three_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 4:
        four_night_c = four_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 5:
        five_night_c = five_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 6:
        six_night_c = six_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 7:
        seven_night_c = seven_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 8:
        eight_night_c = eight_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] == 9:
        nine_night_c = nine_night_c + 1
        
for index in range(40061,119390):
    if len_stay[index] >= 10:
        overten_night_c = overten_night_c + 1
        
print(one_night_c)
print(two_night_c)
print(three_night_c)
print(four_night_c)
print(five_night_c)
print(six_night_c)
print(seven_night_c)
print(eight_night_c)
print(nine_night_c)
print(overten_night_c)
# Out:
# 7748
# 6217
# 5695
# 4826
# 2787
# 1798
# 6596
# 776
# 628
# 2605
# 13272
# 21425
# 21381
# 12557
# 4997
# 2059
# 2059
# 385
# 213
# 650

# %%
leadtime = df.lead_time
canceled = df.is_canceled
cout0_1 = 0;
cout1_2 = 0;
cout2_3 = 0;
cout3_4 = 0;
cout4_5 = 0;
for index in range(0,40060):
    if leadtime[index] <= 7 and leadtime[index] >= 0 and canceled[index]==1:
        cout0_1 = cout0_1 + 1
for index in range(0,40060):
    if leadtime[index] <= 90 and leadtime[index] >= 7 and canceled[index]==1:
        cout1_2 = cout1_2 + 1
        
for index in range(0,40060):
    if leadtime[index] <= 180 and leadtime[index] >= 90 and canceled[index]==1:
        cout2_3 = cout2_3 + 1
        
for index in range(0,40060):
    if leadtime[index] <= 365 and leadtime[index] >= 180 and canceled[index]==1:
        cout3_4 = cout3_4 + 1
for index in range(0,40060):
    if leadtime[index] >= 365 and canceled[index]==1:
        cout4_5 = cout4_5 + 1
        
#people

pep0_1 = 0;
pep1_2 = 0;
pep2_3 = 0;
pep3_4 = 0;
pep4_5 = 0;

for index in range(0,40060):
    if leadtime[index] <= 7 and leadtime[index] >= 0 :
        pep0_1 = pep0_1 + 1
for index in range(0,40060):
    if leadtime[index] <= 90 and leadtime[index] >= 7:
        pep1_2 = pep1_2 + 1
        
for index in range(0,40060):
    if leadtime[index] <= 180 and leadtime[index] >= 90 :
        pep2_3 = pep2_3 + 1
        
for index in range(0,40060):
    if leadtime[index] <= 365 and leadtime[index] >= 180:
        pep3_4 = pep3_4 + 1
        
for index in range(0,40060):
    if leadtime[index] >= 365:
        pep4_5 = pep4_5 + 1
        
print(cout0_1)
print(cout1_2)
print(cout2_3)
print(cout3_4)
print(cout4_5)

print(pep0_1)
print(pep1_2)
print(pep2_3)
print(pep3_4)
print(pep4_5)

        
        
print(cout0_1/pep0_1)
print(cout1_2/pep1_2)
print(cout2_3/pep2_3)
print(cout3_4/pep3_4)
print(cout4_5/pep4_5)
#################################
ccout0_1 = 0;
ccout1_2 = 0;
ccout2_3 = 0;
ccout3_4 = 0;
ccout4_5 = 0;
for index in range(40061,119390):
    if leadtime[index] <= 7 and leadtime[index] >= 0 and canceled[index]==1:
        ccout0_1 = ccout0_1 + 1
for index in range(40061,119390):
    if leadtime[index] <= 90 and leadtime[index] >= 7 and canceled[index]==1:
        ccout1_2 = ccout1_2 + 1
        
for index in range(40061,119390):
    if leadtime[index] <= 180 and leadtime[index] >= 90 and canceled[index]==1:
        ccout2_3 = ccout2_3 + 1
        
for index in range(40061,119390):
    if leadtime[index] <= 365 and leadtime[index] >= 180 and canceled[index]==1:
        ccout3_4 = ccout3_4 + 1
for index in range(40061,119390):
    if leadtime[index] >= 365 and canceled[index]==1:
        ccout4_5 = ccout4_5 + 1
        
#people

cpep0_1 = 0;
cpep1_2 = 0;
cpep2_3 = 0;
cpep3_4 = 0;
cpep4_5 = 0;

for index in range(40061,119390):
    if leadtime[index] <= 7 and leadtime[index] >= 0 :
        cpep0_1 = cpep0_1 + 1
for index in range(40061,119390):
    if leadtime[index] <= 90 and leadtime[index] >= 7:
        cpep1_2 = cpep1_2 + 1
        
for index in range(40061,119390):
    if leadtime[index] <= 180 and leadtime[index] >= 90 :
        cpep2_3 = cpep2_3 + 1
        
for index in range(40061,119390):
    if leadtime[index] <= 365 and leadtime[index] >= 180:
        cpep3_4 = cpep3_4 + 1
        
for index in range(40061,119390):
    if leadtime[index] >= 365:
        cpep4_5 = cpep4_5 + 1
        
print(ccout0_1)
print(ccout1_2)
print(ccout2_3)
print(ccout3_4)
print(ccout4_5)

print(cpep0_1)
print(cpep1_2)
print(cpep2_3)
print(cpep3_4)
print(cpep4_5)

        
        
print(ccout0_1/cpep0_1)
print(ccout1_2/cpep1_2)
print(ccout2_3/cpep2_3)
print(ccout3_4/cpep3_4)
print(ccout4_5/cpep4_5)
# Out:
# 583
# 4299
# 3098
# 3037
# 207
# 8938
# 15735
# 8311
# 7368
# 455
# 0.06522712016110986
# 0.27321258341277405
# 0.37275899410419927
# 0.41218783930510317
# 0.45494505494505494
# 1319
# 12297
# 8802
# 9021
# 1977
# 10807
# 34109
# 18421
# 14446
# 2758
# 0.12205052280929027
# 0.36052068369052154
# 0.477824222354921
# 0.6244635193133047
# 0.7168237853517041
